# %% [markdown]
# # Word Frequency Analysis

# %%
# Import required libraries
from pathlib import Path
from datetime import datetime
import logging

# Define constants
LOGS_DIR = Path('logs')
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
LOGS_FILE = LOGS_DIR / f"word_frequency_{timestamp}.log"
PDF_LIST = Path('data/pdf_list.csv')
DB_PATH = Path('data/database.db')

# Set up logging
logging.basicConfig(
    filename=LOGS_FILE,
    level=logging.INFO,
    format='%(asctime)s:%(levelname)s:%(message)s'
    )

# %% [markdown]
# ## Most Frequent Words

# %% [markdown]
# ### Community and non-profit organizations

# %%
from scripts.word_frequency import WordFrequencyChart

chart = WordFrequencyChart(DB_PATH).top_20_words_category(where='Organismes communautaires et à but non-lucratif')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### French corpus

# %%
from scripts.word_frequency import WordFrequencyChart

chart = WordFrequencyChart(DB_PATH).top_20_words_lang(lang='fr')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### English documents

# %%
from scripts.word_frequency import WordFrequencyChart

chart = WordFrequencyChart(DB_PATH).top_20_words_lang(lang='en')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Bilingual Documents

# %%
from scripts.word_frequency import WordFrequencyChart

chart = WordFrequencyChart(DB_PATH).top_20_words_lang(lang='bilingual')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Certain words

# %%
from scripts.word_frequency import WordFrequencyChart

words = [
    'discrimination',
    'racisme',
    'racial',
    'race',
    'raciste',
    'couleur',
    'genre',
    'femme',
    'femme trans',
    'féministe',
    'lgbt',
    'lgbtq',
    'gai',
    'lesbienne',
    'queer',
    'handicap',
    'accessibilité',
    'accessible',
    'religion',
    'islam',
    'musulman'
]

chart = WordFrequencyChart(DB_PATH).frequency_certain_words(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
